# %%
import pandas as pd
import numpy as np

# %%
path = 'C:/Users/jorge/OneDrive/Escritorio/ProyectoJacobo/EnvipeLimpia/TPer_vic2_Clean2017.csv'
df = pd.read_csv(path, low_memory=False)
df.head()
# Out:
#       UPM  VIV_SEL  HOGAR  RESUL_H  R_SEL  SEXO  EDAD  AREAM  CVE_ENT  \
# 0  100008        1      1        2      1     1    40     14        1
# 1  100008        2      1        2      2     2    70     14        1
# 2  100008        4      1        2      1     1    85     14        1
# 3  100008        5      1        1      1     1    28     14        1
# 4  100022        1      1        1      3     1    22     14        1
#
#    NOM_ENT   ...     AP7_3_15  AP7_4_15  FAC_HOG  FAC_ELE  FAC_HOG_AM  \
# 0        1   ...            2        99      204      408         204
# 1        1   ...            2        99      204      611         204
# 2        1   ...            2        99      204      408         204
# 3        1   ...            2        99      204      408         204
# 4        1   ...            2        99      198      595         198
#
#    FAC_ELE_AM  DOMINIO  ESTRATO  EST_DIS  UPM_DIS
# 0         408        1        4        3        1
# ...

# %%
n = df.columns.values.tolist()
m = round(df.shape[0]*.50)
l = []
for i in n:
    if df[i].value_counts().get("TTT") != None:
        if m < df[i].value_counts().get("TTT"):
            l.append(i)
            df = df.drop(i, 1)

# %%
df.head()
# Out:
#       UPM  VIV_SEL  HOGAR  RESUL_H  R_SEL  SEXO  EDAD  AREAM  CVE_ENT  \
# 0  100008        1      1        2      1     1    40     14        1
# 1  100008        2      1        2      2     2    70     14        1
# 2  100008        4      1        2      1     1    85     14        1
# 3  100008        5      1        1      1     1    28     14        1
# 4  100022        1      1        1      3     1    22     14        1
#
#    NOM_ENT   ...     AP7_3_15  AP7_4_15  FAC_HOG  FAC_ELE  FAC_HOG_AM  \
# 0        1   ...            2        99      204      408         204
# 1        1   ...            2        99      204      611         204
# 2        1   ...            2        99      204      408         204
# 3        1   ...            2        99      204      408         204
# 4        1   ...            2        99      198      595         198
#
#    FAC_ELE_AM  DOMINIO  ESTRATO  EST_DIS  UPM_DIS
# 0         408        1        4        3        1
# ...

# %%
df.astype('int64')
# Out:
#            UPM  VIV_SEL  HOGAR  RESUL_H  R_SEL  SEXO  EDAD  AREAM  CVE_ENT  \
# 0       100008        1      1        2      1     1    40     14        1
# 1       100008        2      1        2      2     2    70     14        1
# 2       100008        4      1        2      1     1    85     14        1
# 3       100008        5      1        1      1     1    28     14        1
# 4       100022        1      1        1      3     1    22     14        1
# 5       100022        2      1        1      1     1    34     14        1
# 6       100022        3      1        2      1     1    24     14        1
# 7       100022        5      1        1      3     1    34     14        1
# 8       100059        1      1        1      3     2    33     14        1
# 9       100059        2      1        2      1     1    25     14        1
# 10      100059        3      1        1      1     1    47     14        1
# ...

# %%
n = df.columns.values.tolist()
m = round(df.shape[0]*.50)
l = []
for i in n:
    if df[i].value_counts().get(99) != None:
        if m < df[i].value_counts().get(99):
            l.append(i)
            df = df.drop(i, 1)

# %%
df.head()
# Out:
#       UPM  VIV_SEL  HOGAR  RESUL_H  R_SEL  SEXO  EDAD  CVE_ENT  NOM_ENT  \
# 0  100008        1      1        2      1     1    40        1        1
# 1  100008        2      1        2      2     2    70        1        1
# 2  100008        4      1        2      1     1    85        1        1
# 3  100008        5      1        1      1     1    28        1        1
# 4  100022        1      1        1      3     1    22        1        1
#
#    CVE_MUN   ...     AP7_3_12  AP7_3_13  AP7_3_14  AP7_3_15  FAC_HOG  FAC_ELE  \
# 0        1   ...            2         2         2         2      204      408
# 1        1   ...            2         2         2         2      204      611
# 2        1   ...            2         2         2         2      204      408
# 3        1   ...            2         2         2         2      204      408
# 4        1   ...            2         2         2         2      198      595
#
#    DOMINIO  ESTRATO  EST_DIS  UPM_DIS
# ...

# %%
n = df.columns.values.tolist()
for i in n:
    if df[i].value_counts().get("TTT") != None:
        if df[i].mode().tolist()[0] == 'TTT':
            m = df.drop(df[(df[i] == 'TTT')].index)
            m= m[i].mode().tolist()
            df[i].replace({'TTT':m[0]}, inplace=True)
        else:
            df[i].replace({'TTT':df[i].mode().tolist()[0]}, inplace=True)
df.head()
# Out:
#       UPM  VIV_SEL  HOGAR  RESUL_H  R_SEL  SEXO  EDAD  CVE_ENT  NOM_ENT  \
# 0  100008        1      1        2      1     1    40        1        1
# 1  100008        2      1        2      2     2    70        1        1
# 2  100008        4      1        2      1     1    85        1        1
# 3  100008        5      1        1      1     1    28        1        1
# 4  100022        1      1        1      3     1    22        1        1
#
#    CVE_MUN   ...     AP7_3_12  AP7_3_13  AP7_3_14  AP7_3_15  FAC_HOG  FAC_ELE  \
# 0        1   ...            2         2         2         2      204      408
# 1        1   ...            2         2         2         2      204      611
# 2        1   ...            2         2         2         2      204      408
# 3        1   ...            2         2         2         2      204      408
# 4        1   ...            2         2         2         2      198      595
#
#    DOMINIO  ESTRATO  EST_DIS  UPM_DIS
# ...

# %%
n = df.columns.values.tolist()
for i in n:
    if df[i].value_counts().get(99) != None:
        if df[i].value_counts().get(9) == None:
            df[i].replace({99 : 9},inplace = True)
df.head()
# Out:
#       UPM  VIV_SEL  HOGAR  RESUL_H  R_SEL  SEXO  EDAD  CVE_ENT  NOM_ENT  \
# 0  100008        1      1        2      1     1    40        1        1
# 1  100008        2      1        2      2     2    70        1        1
# 2  100008        4      1        2      1     1    85        1        1
# 3  100008        5      1        1      1     1    28        1        1
# 4  100022        1      1        1      3     1    22        1        1
#
#    CVE_MUN   ...     AP7_3_12  AP7_3_13  AP7_3_14  AP7_3_15  FAC_HOG  FAC_ELE  \
# 0        1   ...            2         2         2         2      204      408
# 1        1   ...            2         2         2         2      204      611
# 2        1   ...            2         2         2         2      204      408
# 3        1   ...            2         2         2         2      204      408
# 4        1   ...            2         2         2         2      198      595
#
#    DOMINIO  ESTRATO  EST_DIS  UPM_DIS
# ...

# %%
df.to_csv("TPer_vic2_Clean2017_V3.csv")
